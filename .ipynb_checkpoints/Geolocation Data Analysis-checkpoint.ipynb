# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
import matplotlib.cm as cm
import folium
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# %%
# %matplotlib inline

# %% [markdown]
# # Import data set

# %%
df = pd.read_csv('food_coded.csv')

# %% [markdown]
# # Removing all the features that are not needed.
# # all the non numerical, and features that have little effect on,
# # deciding a place to live, are removed.

# %%
droping = ['GPA',
 'Gender',
 'breakfast',
 'calories_chicken',
 'calories_day',
 'calories_scone',
 'coffee',
 'comfort_food',
 'comfort_food_reasons',
 'comfort_food_reasons_coded',
 'comfort_food_reasons_coded.1',
 'cuisine',
 'diet_current',
 'diet_current_coded',
 'drink',
 'eating_changes',
 'eating_changes_coded',
 'eating_changes_coded1',
 'father_education',
 'father_profession',
 'fav_cuisine',
 'fav_cuisine_coded',
 'fav_food',
 'food_childhood',
 'fries',
 'grade_level',
 'greek_food',
 'healthy_feeling',
 'healthy_meal',
 'ideal_diet',
 'ideal_diet_coded',
 'indian_food',
 'italian_food',
 'life_rewarding',
 'marital_status',
 'meals_dinner_friend',
 'mother_education',
 'mother_profession',
 'nutritional_check',
 'persian_food',
 'self_perception_weight',
 'soup','thai_food',
 'tortilla_calories',
 'turkey_calories',
 'type_sports','vitamins',
 'waffle_calories',
 'weight']
df3 = df.drop(droping, axis=1)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cook           122 non-null    float64
#  1   eating_out     125 non-null    int64
#  2   employment     116 non-null    float64
#  3   ethnic_food    125 non-null    int64
#  4   exercise       112 non-null    float64
#  5   fruit_day      125 non-null    int64
#  6   income         124 non-null    float64
#  7   on_off_campus  124 non-null    float64
#  8   parents_cook   125 non-null    int64
#  9   pay_meal_out   125 non-null    int64
#  10  sports         123 non-null    float64
#  11  veggies_day    125 non-null    int64
# dtypes: float64(6), int64(6)
# memory usage: 11.8 KB

# %% [markdown]
# # Replacing all the null values with the current mean of the features

# %%
m1, m2, m3, m4, m5, m6 = 0, 0, 0, 0, 0, 0
m1, m2, m3, m4, m5, m6 = df3['employment'].mean(), df3['exercise'].mean(),df3['income'].mean(), df3['on_off_campus'].mean(), df3['sports'].mean(), df3['cook'].mean()
df3['employment'].fillna(m1, inplace=True)
df3['exercise'].fillna(m2, inplace=True)
df3['income'].fillna(m3, inplace=True)
df3['on_off_campus'].fillna(m4, inplace=True)
df3['sports'].fillna(m5, inplace=True)
df3['cook'].fillna(m6, inplace=True)

# %%
df3.head()
# Out:
#    cook  eating_out  employment  ethnic_food  exercise  fruit_day  income  \
# 0   2.0           3         3.0            1       1.0          5     5.0
# 1   3.0           2         2.0            4       1.0          4     4.0
# 2   1.0           2         3.0            5       2.0          5     6.0
# 3   2.0           2         3.0            5       3.0          4     6.0
# 4   1.0           2         2.0            4       1.0          4     6.0
#
#    on_off_campus  parents_cook  pay_meal_out  sports  veggies_day
# 0            1.0             1             2     1.0            5
# 1            1.0             1             4     1.0            4
# 2            2.0             1             3     2.0            5
# 3            1.0             1             2     2.0            3
# 4            1.0             1             4     1.0            4

# %% [markdown]
# # Visualizing using the 'boxplot' of the seaborn library.

# %%
plt.figure(figsize=(20, 10))
sns.boxplot

ax = sns.boxplot(data = df3)
ax.tick_params(labelsize=20)
plt.xticks(rotation=45, ha='right')

plt.show()

# %% [markdown]
# # it seems that people prefer to eat out less regardless of income
# # preference of ethinc food seems to increased with the income
# # people eat more fruits with more income(according to data at least)

# %%
# set number of clusters
kclusters = 3

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df3)
df3['Cluster']=kmeans.labels_

# %%
fig, axes = plt.subplots(1,kclusters, figsize=(20, 10), sharey=True)
axes[0].set_ylabel('Coded Values', fontsize=25)

for k in range(kclusters):
     plt.sca(axes[k])
     plt.xticks(rotation=45,ha='right')
     sns.boxplot(data = df3[df3['Cluster'] == k].drop('Cluster',1), ax=axes[k])
        
plt.show()
# Out:
# C:\Users\ROHITS~1\AppData\Local\Temp/ipykernel_15916/666216582.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   sns.boxplot(data = df3[df3['Cluster'] == k].drop('Cluster',1), ax=axes[k])
# C:\Users\ROHITS~1\AppData\Local\Temp/ipykernel_15916/666216582.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   sns.boxplot(data = df3[df3['Cluster'] == k].drop('Cluster',1), ax=axes[k])
# C:\Users\ROHITS~1\AppData\Local\Temp/ipykernel_15916/666216582.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   sns.boxplot(data = df3[df3['Cluster'] == k].drop('Cluster',1), ax=axes[k])

# %% [markdown]
# # People with less income
# 1. people with less income(according to the data) tend to eat out less.
# 2. People with less income prefer to cook at home are or are more likely to cook at home.
# 3. People with less income eat out less often and want to buy grocries for home cook.
#
# # People with more income
# 1. As the income people increases(according to the data) their preference for ethnic food increases.
# 2. It is the same with food, they want to eat more fruits.
# 3. preference of veggies of veggies is also increased.
#
# In conclusion the the people with less income need more shops and groceries around their place to buy veggies for home cook.
#
# People with more need prefer to have ethnic restaurant around them, and shop to buy fruits
#
#
# # The number of clusters choose is 3 because it seems that data is nicely clustered around, income
# # Any less than that the visualization is messy
# # And more than that the visualization is also messy

# %%
search_query = 'PG Apartments' #Search for residential locations 28.364628, 77.539879
radius = 30000 #Set the radius to 30 kilometres due to remote college location
latitude=28.364628 #College location(Galgotia's University)
longitude=77.539879
college = 'Galgotias University'

# %%
CLIENT_ID = 'S0KV55VKN1SDRR2B2Z1TIMA33Y230VSBQSFTQ1ASVJEUGSME'#  
CLIENT_SECRET = 'L3Y3A3KCDNGSTD32Y2XTQQ0GEVU2WVYEFXPI1RPRU2PRJFTT' # 
VERSION = '20210604'
LIMIT = 200

# %%
url = f'https://api.foursquare.com/v2/venues/search?client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&ll={latitude},{longitude}&v={VERSION}&query={search_query}&radius={radius}&limit={LIMIT}'

# %%
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# C:\Users\ROHITS~1\AppData\Local\Temp/ipykernel_15916/4005429704.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)
#                          id                   name  \
# 0  535f3271498ee48607aea91a              PGDM Hall
# 1  4ec168ae30f82a2e13d52a40  Black Gold Apartments
# 2  4c80bcc7d34ca143a8ab1b80        Icon Apartments
# 3  57d1c577498efd6248631caf    Sai Park Apartments
# 4  51e4f94a498e834f69f32da2            Abhishek PG
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1a0941735', 'name': 'C...  v-1638250871    False
# 1  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1638250871    False
# 2                                                 []  v-1638250871    False
# 3  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1638250871    False
# 4  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1638250871    False
#
#    location.lat  location.lng  \
# 0     28.470884     77.482033
# 1     28.455142     77.514105
# 2     28.461677     77.515641
# 3     28.412214     77.336770
# 4     28.541406     77.335435
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 28.47088432312011...              13114
# 1  [{'label': 'display', 'lat': 28.45514197248049...              10387
# 2  [{'label': 'display', 'lat': 28.461677, 'lng':...              11060
# 3  [{'label': 'display', 'lat': 28.412214, 'lng':...              20584
# 4  [{'label': 'display', 'lat': 28.54140570515523...              28064
#
#   location.cc location.country  \
# 0          IN            India
# 1          IN            India
# 2          IN            India
# 3          IN            India
# 4          IN            India
#
#                            location.formattedAddress location.city  \
# 0                                            [India]           NaN
# 1                                            [India]           NaN
# 2                                            [India]           NaN
# 3                        [Farīdābād, Haryāna, India]     Farīdābād
# 4  [Sector 126 (Opposite Amity Gate 2), Noida 201...         Noida
#
#   location.state location.address   location.crossStreet location.postalCode
# 0            NaN              NaN                    NaN                 NaN
# 1            NaN              NaN                    NaN                 NaN
# 2            NaN              NaN                    NaN                 NaN
# 3        Haryāna              NaN                    NaN                 NaN
# 4  Uttar Pradesh       Sector 126  Opposite Amity Gate 2              201304

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
dataframe_filtered.drop([0, 37, 17, 23, 26,27, 34, 28, 40],axis=0,inplace=True) #remove some unwanted locations like hotels
dataframe_filtered.drop(['cc','country','state','city'],axis=1,inplace=True) #no need for those columns as we know we're in Greater Noida,IN
dataframe_filtered
# Out:
#                                          name  \
# 1                       Black Gold Apartments
# 2                             Icon Apartments
# 3                         Sai Park Apartments
# 4                                 Abhishek PG
# 5         Madhuban Apartments Sector 82 Noida
# 6   pg near amity university sector 125 noida
# 7                     Express View Apartments
# 8                                 Aggarwal PG
# 9                          Shivlok Apartments
# 10                       Golf Link Apartments
# 11                           Shiva Apartments
# 12                                  Neelus Pg
# 13                            Shanti Niwas PG
# 14                                         Pg
# 15                             Omega Green PG
# 16                          PG, B 38sector 26
# 18                      Government PG College
# 19                                Sujata's PG
# 20             PG - temporary shelter @sec 26
# 21                               Bhutani's PG
# 22                                    Rana PG
# 24                  Lotus serviced apartments
# 25                     Silver Leaf Apartments
# 29                         Mahavir Apartments
# 30                                    City PG
# 31                       Club View Apartments
# 32                       Park view Apartments
# 33                       Millenium apartments
# 35                         D P Gupta's office
# 36                 DDA Apartments Pocket 10 B
# 38           Churchview apartments  Sector 29
# 39                            Flex Apartments
# 41                        Oriental Apartments
# 42                             MEA Apartments
# 43                  Gaurav Ahikari Apartments
# 44                        Fortview Apartments
# 45           Badminton Court- Tara Apartments
# 46                      Bhagirathi Apartments
# 47                            Gail Apartments
# 48                          Vishal Apartments
# 49                            Tara Apartments
#
#                                   categories        lat        lng  \
# 1   Residential Building (Apartment / Condo)  28.455142  77.514105
# 2                                       None  28.461677  77.515641
# 3   Residential Building (Apartment / Condo)  28.412214  77.336770
# 4   Residential Building (Apartment / Condo)  28.541406  77.335435
# 5   Residential Building (Apartment / Condo)  28.528105  77.387211
# 6                     College Residence Hall  28.542005  77.337828
# 7   Residential Building (Apartment / Condo)  28.520818  77.388815
# 8                                   Building  28.481140  77.307317
# 9   Residential Building (Apartment / Condo)  28.422414  77.291669
# 10  Residential Building (Apartment / Condo)  28.432936  77.290485
# 11  Residential Building (Apartment / Condo)  28.422234  77.293106
# 12                           Assisted Living  28.576118  77.332451
# 13  Residential Building (Apartment / Condo)  28.542465  77.338409
# 14               Professional & Other Places  28.596301  77.364597
# 15                           Assisted Living  28.554485  77.336914
# 16                           Assisted Living  28.579573  77.333923
# 18                 College Academic Building  28.573386  77.355696
# 19  Residential Building (Apartment / Condo)  28.560168  77.333756
# 20                           Assisted Living  28.580653  77.332799
# 21  Residential Building (Apartment / Condo)  28.584864  77.309870
# 22                       Housing Development  28.592377  77.347076
# 24                                     Hotel  28.572896  77.362016
# 25  Residential Building (Apartment / Condo)  28.576339  77.360000
# 29  Residential Building (Apartment / Condo)  28.571264  77.336138
# 30  Residential Building (Apartment / Condo)  28.608053  77.354541
# 31  Residential Building (Apartment / Condo)  28.568337  77.333314
# 32  Residential Building (Apartment / Condo)  28.570218  77.334145
# 33  Residential Building (Apartment / Condo)  28.598442  77.369921
# 35                                    Office  28.532703  77.264343
# 36  Residential Building (Apartment / Condo)  28.545467  77.291340
# 38  Residential Building (Apartment / Condo)  28.566313  77.336752
# 39  Residential Building (Apartment / Condo)  28.611595  77.369560
# 41  Residential Building (Apartment / Condo)  28.614481  77.369388
# 42                                  Building  28.616155  77.370359
# 43  Residential Building (Apartment / Condo)  28.614001  77.372573
# 44  Residential Building (Apartment / Condo)  28.527524  77.265695
# 45                                      None  28.526391  77.257019
# 46  Residential Building (Apartment / Condo)  28.623565  77.369054
# 47  Residential Building (Apartment / Condo)  28.620869  77.369769
# 48  Residential Building (Apartment / Condo)  28.595383  77.319351
# 49                                  Building  28.523738  77.255756
#
#                                        labeledLatLngs  distance  \
# 1   [{'label': 'display', 'lat': 28.45514197248049...     10387
# 2   [{'label': 'display', 'lat': 28.461677, 'lng':...     11060
# 3   [{'label': 'display', 'lat': 28.412214, 'lng':...     20584
# 4   [{'label': 'display', 'lat': 28.54140570515523...     28064
# 5   [{'label': 'display', 'lat': 28.52810497971240...     23546
# 6   [{'label': 'display', 'lat': 28.54200502571147...     27945
# 7   [{'label': 'display', 'lat': 28.52081806039613...     22824
# 8   [{'label': 'display', 'lat': 28.4811399, 'lng'...     26202
# 9   [{'label': 'display', 'lat': 28.4224137690903,...     25143
# 10  [{'label': 'display', 'lat': 28.432936, 'lng':...     25577
# 11  [{'label': 'display', 'lat': 28.422234, 'lng':...     25002
# 12  [{'label': 'display', 'lat': 28.57611846923828...     31085
# 13  [{'label': 'display', 'lat': 28.54246520996093...     27941
# 14  [{'label': 'display', 'lat': 28.59630079, 'lng...     30971
# 15  [{'label': 'display', 'lat': 28.55448532104492...     29003
# 16  [{'label': 'display', 'lat': 28.57957267761230...     31284
# 18  [{'label': 'display', 'lat': 28.573386, 'lng':...     29409
# 19  [{'label': 'display', 'lat': 28.560168, 'lng':...     29676
# 20  [{'label': 'display', 'lat': 28.58065318811461...     31446
# 21  [{'label': 'display', 'lat': 28.584864, 'lng':...     33280
# 22  [{'label': 'display', 'lat': 28.59237670898437...     31601
# 24  [{'label': 'display', 'lat': 28.57289592866220...     28990
# 25  [{'label': 'display', 'lat': 28.576339, 'lng':...     29415
# 29  [{'label': 'display', 'lat': 28.571264, 'lng':...     30440
# 30  [{'label': 'display', 'lat': 28.60805287065184...     32605
# 31  [{'label': 'display', 'lat': 28.568337, 'lng':...     30378
# 32  [{'label': 'display', 'lat': 28.57021771173241...     30481
# 33  [{'label': 'display', 'lat': 28.59844209143087...     30886
# 35  [{'label': 'display', 'lat': 28.53270290856821...     32823
# 36  [{'label': 'display', 'lat': 28.545467, 'lng':...     31574
# 38  [{'label': 'display', 'lat': 28.56631299065095...     29986
# 39  [{'label': 'display', 'lat': 28.61159515380859...     32148
# 41  [{'label': 'display', 'lat': 28.6144811008126,...     32431
# 42  [{'label': 'display', 'lat': 28.61615499653717...     32543
# 43  [{'label': 'display', 'lat': 28.61400131234549...     32226
# 44  [{'label': 'display', 'lat': 28.527524, 'lng':...     32388
# 45  [{'label': 'display', 'lat': 28.52639138963421...     33027
# 46  [{'label': 'display', 'lat': 28.623565, 'lng':...     33319
# 47  [{'label': 'display', 'lat': 28.62086912947189...     33024
# 48  [{'label': 'display', 'lat': 28.595383, 'lng':...     33547
# 49  [{'label': 'display', 'lat': 28.52373797939428...     32971
#
#                                      formattedAddress  \
# 1                                             [India]
# 2                                             [India]
# 3                         [Farīdābād, Haryāna, India]
# 4   [Sector 126 (Opposite Amity Gate 2), Noida 201...
# 5                                             [India]
# 6   [Plot Number- 10, Raipur Khadar, Noida Sector ...
# 7                              [Greater Noida, India]
# 8   [12/2 Mathura road (sector 37), Farīdābād 1210...
# 9                                             [India]
# 10                                            [India]
# 11     [Sector 21D, Farīdābād 121012, Haryāna, India]
# 12  [A 62, Sector 27, Noida, Noida 201301, Uttar P...
# 13  [Sector 126 (Raipur), Noida 201304, Uttar Prad...
# 14  [SHOPRIX,SECTOR 61, New Okhla Industrial Devel...
# 15                                            [India]
# 16                                            [India]
# 18       [I-1 Sector 39, Noida, Uttar Pradesh, India]
# 19    [B 28 (Sector 44), Noida, Uttar Pradesh, India]
# 20         [B-3, sec-26, Noida, Uttar Pradesh, India]
# 21  [A2 (Sector 15), Noida 201301, Uttar Pradesh, ...
# 22                                            [India]
# 24                                            [India]
# 25    [A 66 (Sector 51), Noida, Uttar Pradesh, India]
# 29    [Sector 29, Noida 201303, Uttar Pradesh, India]
# 30           [Sector 58, Noida, Uttar Pradesh, India]
# 31                      [Noida, Uttar Pradesh, India]
# 32  [Sector 29, Noida, Uttar Pradesh, Noida 201303...
# 33                          [Sector 61, Noida, India]
# 35                                            [India]
# 36                                            [India]
# 38                                            [India]
# 39                                            [India]
# 41    [Sector 62, Noida 201309, Uttar Pradesh, India]
# 42  [New Okhla Industrial Developme 201307, Uttar ...
# 43  [New Okhla Industrial Developme, Uttar Pradesh...
# 44  [Pocket 13A (Kalkaji Extension), New Delhi 110...
# 45  [Tara Apartments (Alakhnanda), New Delhi 11001...
# 46  [B9/14 Bhagirathi Apartments (Sector 62), Noid...
# 47  [Plot B9/1, New Okhla Industrial Developme 201...
# 48                                            [India]
# 49       [Alakhnanda, New Delhi 110019, Delhi, India]
#
#                                               address            crossStreet  \
# 1                                                 NaN                    NaN
# 2                                                 NaN                    NaN
# 3                                                 NaN                    NaN
# 4                                          Sector 126  Opposite Amity Gate 2
# 5                                                 NaN                    NaN
# 6   Plot Number- 10, Raipur Khadar, Noida Sector 1...          Raipur Khadar
# 7                                       Greater Noida                    NaN
# 8                                   12/2 Mathura road              sector 37
# 9                                                 NaN                    NaN
# 10                                                NaN                    NaN
# 11                                         Sector 21D                    NaN
# 12                             A 62, Sector 27, Noida                    NaN
# 13                                         Sector 126                 Raipur
# 14                                  SHOPRIX,SECTOR 61                    NaN
# 15                                                NaN                    NaN
# 16                                                NaN                    NaN
# 18                                      I-1 Sector 39                    NaN
# 19                                               B 28              Sector 44
# 20                                        B-3, sec-26                    NaN
# 21                                                 A2              Sector 15
# 22                                                NaN                    NaN
# 24                                                NaN                    NaN
# 25                                               A 66              Sector 51
# 29                                          Sector 29                    NaN
# 30                                          Sector 58                    NaN
# 31                                                NaN                    NaN
# 32                    Sector 29, Noida, Uttar Pradesh                    NaN
# 33                                                NaN              Sector 61
# 35                                                NaN                    NaN
# 36                                                NaN                    NaN
# 38                                                NaN                    NaN
# 39                                                NaN                    NaN
# 41                                          Sector 62                    NaN
# 42                                                NaN                    NaN
# 43                                                NaN                    NaN
# 44                                         Pocket 13A      Kalkaji Extension
# 45                                    Tara Apartments             Alakhnanda
# 46                        B9/14 Bhagirathi Apartments              Sector 62
# 47                                          Plot B9/1                    NaN
# 48                                                NaN                    NaN
# 49                                         Alakhnanda                    NaN
#
#    postalCode                        id
# 1         NaN  4ec168ae30f82a2e13d52a40
# 2         NaN  4c80bcc7d34ca143a8ab1b80
# 3         NaN  57d1c577498efd6248631caf
# 4      201304  51e4f94a498e834f69f32da2
# 5         NaN  515da674e4b02a986c4cb74d
# 6      201303  5b6beb7d6f0aa2002cb9e56d
# 7         NaN  50f3b79ae4b048197e793d10
# 8      121003  4cfd15157f2db1f7ed2936d4
# 9         NaN  55c13095498ee7997d4d5b90
# 10        NaN  529a16b3498ea48259833912
# 11     121012  58e8c766d4ab7360a88c5703
# 12     201301  520b9fb411d261f510e82bc5
# 13     201304  50f28cb0e4b0d13e7cb9e53f
# 14        NaN  4dd52b4f8877e2b7c5e9f883
# 15        NaN  521b422811d2c3fe5a8f0640
# 16        NaN  52992ff611d2ce1a3455be75
# 18        NaN  5316c684498e2bb832c08bf1
# 19        NaN  51e28676498e6768a9d9472c
# 20        NaN  51afde76498e1bc434373232
# 21     201301  4f353d8be4b03d9aaafd6b4c
# 22        NaN  509d642be4b0bbf775bfc144
# 24        NaN  52f59d48498e83d64d478010
# 25        NaN  5143f14ae4b0df5d4e266576
# 29     201303  5bbe849e2b9844002c490f67
# 30        NaN  4f37ee55e4b0d3ab51f8de91
# 31        NaN  517cdc48e4b0314595bdc341
# 32     201303  4f86941ae4b0c69e7d473688
# 33        NaN  4f06a150e4b0671f25b513bb
# 35        NaN  5377232f498e8528a6663401
# 36        NaN  574f461d498e1c34421d169b
# 38        NaN  5378f606498e037ae8ca1913
# 39        NaN  4f5b3871e4b09f0f97937227
# 41     201309  57f92a07498eab93faeda9a6
# 42     201307  4d6e3ccb383637042eeaa4d0
# 43        NaN  4e00b156483bd352f71efb21
# 44     110019  560558af498ecb203ed7bbd1
# 45     110019  4e4f28a41495fc2ca3fbf64f
# 46     201301  581ea568fb482d7efa3548cd
# 47     201301  4ddd41c2b0fba481fc949f08
# 48        NaN  55fec956498e70097a0acaf7
# 49     110019  4d3da4246e0aa1cd07a9ed2c

# %%
#define coordinates of the college

def fun(dist):
    """To extract location distance from the filtered data, in Kilometers"""
    return f"{dist/1000}"
map_Galgotia=folium.Map(location=[28.364628,77.539879],zoom_start=12)
# Marking College on the Map with red color.
folium.Marker([28.364628, 77.539879], popup=college, tooltip="Galgoitas University").add_to(map_Galgotia) 
# instantiate a feature group for the incidents in the dataframe
locations = folium.map.FeatureGroup()

latitudes = list(dataframe_filtered.lat)
longitudes = list( dataframe_filtered.lng)
names = list(dataframe_filtered.name)
distance = list(dataframe_filtered.distance.apply(fun)) # extracting distance from the data


for lat, lng, name, dist in zip(latitudes, longitudes, names, distance):
    color = 'green'
    d = float(dist)
    if d >= 10 and d < 20:
        color = 'green'
    elif d >= 20 and d <= 30:
        
        color = 'orange'
    elif d > 30 and d <= 35:
        color = 'red'
    else:
        color = 'darkred'
    
    folium.Marker([lat, lng], popup=f"{name}, {dist} KM",icon=folium.Icon(color=color), tooltip=name).add_to(map_Galgotia)    
    
# add incidents to map
map_Galgotia.add_child(locations)

# add incidents to map
map_Galgotia.add_child(locations)
map_Galgotia

#10-20 green, 20 - 25 yellow , 25 > red
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_80d82674e8244d2c952772cccc93e7c4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_80d82674e8244d2c952772cccc93e7c4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_80d82674e8244d2c952772cccc93e7c4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_80d82674e8244d2c952772cccc93e7c4%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B28.364628%2C%2077.539879%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# # Conclusion
# 1. There were no location around University, within 10 KM, and only two locations between 10 and 11 KM, that too are apartments.
# 2. The location data around Galgotias University is not very good, thus there might be some locations that didn't reflect in the above map
# 3. Students can look for apartments **around**, 'Knowledge Park' Area.
# 4. For better analysis need more data around the locations.
# 5. As we cross the 20 KM mark we start to see some PGs and more apartments, there are pgs **around** Amity university
# 6. You would need a transport facility to drop and pick you up from the univeristy.
# 7. PGs are more clustered around Noida, but they are at a distance of more than 25 KM
# 8. There is one more university around Galgotias University, so business owners should think about building something there, that accomodates the students there.
